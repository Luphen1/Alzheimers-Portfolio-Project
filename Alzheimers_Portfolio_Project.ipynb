# %%
#import libries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import and inspect dataframe.
df = pd.read_csv(r"C:\Users\LUPHEN\Desktop\Cleaned_Dataset\Kaggle Pantings Datasets\alzheimers_prediction_dataset.csv")
df.sample(10)
# Out:
#             Country  Age  Gender  Education Level   BMI  \
# 69195         Italy   70    Male               18  32.0
# 21816  South Africa   73  Female               18  32.2
# 31818     Argentina   65  Female                8  23.3
# 69316       Germany   86  Female               16  32.1
# 484          France   77  Female               14  26.6
# 2865         Brazil   81    Male                2  19.3
# 64743        Norway   51  Female               16  33.9
# 27690         Japan   68    Male               12  33.4
# 23687        Canada   85    Male                8  22.2
# 19876         India   90    Male                4  33.2
#
#       Physical Activity Level Smoking Status Alcohol Consumption Diabetes  \
# 69195                     Low         Former           Regularly       No
# 21816                    High         Former        Occasionally       No
# 31818                  Medium         Former        Occasionally       No
# ...

# %%
#Column Overview
df.columns
# Out:
# Index(['Country', 'Age', 'Gender', 'Education Level', 'BMI',
#        'Physical Activity Level', 'Smoking Status', 'Alcohol Consumption',
#        'Diabetes', 'Hypertension', 'Cholesterol Level',
#        'Family History of Alzheimerâs', 'Cognitive Test Score',
#        'Depression Level', 'Sleep Quality', 'Dietary Habits',
#        'Air Pollution Exposure', 'Employment Status', 'Marital Status',
#        'Genetic Risk Factor (APOE-Îµ4 allele)', 'Social Engagement Level',
#        'Income Level', 'Stress Levels', 'Urban vs Rural Living',
#        'Alzheimerâs Diagnosis'],
#       dtype='object')

# %%
#Statistic Overview.
stastistic_review = df.describe()
stastistic_review
# Out:
#                 Age  Education Level           BMI  Cognitive Test Score
# count  74283.000000     74283.000000  74283.000000          74283.000000
# mean      71.964703         9.487514     26.780639             64.654241
# std       12.980748         5.757020      4.764679             20.153247
# min       50.000000         0.000000     18.500000             30.000000
# 25%       61.000000         4.000000     22.700000             47.000000
# 50%       72.000000         9.000000     26.800000             65.000000
# 75%       83.000000        14.000000     30.900000             82.000000
# max       94.000000        19.000000     35.000000             99.000000

# %%
#Check for duplicate values.
dup_check = df.duplicated().sum()
print("dup_check:",dup_check)
# Out:
# dup_check: 0

# %%
#Check for dataframe datatypes.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74283 entries, 0 to 74282
# Data columns (total 25 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Country                                74283 non-null  object
#  1   Age                                    74283 non-null  int64
#  2   Gender                                 74283 non-null  object
#  3   Education Level                        74283 non-null  int64
#  4   BMI                                    74283 non-null  float64
#  5   Physical Activity Level                74283 non-null  object
#  6   Smoking Status                         74283 non-null  object
#  7   Alcohol Consumption                    74283 non-null  object
#  8   Diabetes                               74283 non-null  object
#  9   Hypertension                           74283 non-null  object
# ...

# %%
#Plot and dectect outliers in columns  
fig,axes = plt.subplots(nrows = 4 , figsize=(17,22) )

#Plot and detect outlier for column age.
sns.boxplot(x = df["Age"], ax = axes[0])
axes[0].set_title("Outliers for age")

#Plot and detect outlier for column age.                 
sns.boxplot(x = df["Education Level"], ax = axes[1])
axes[1].set_title("Outliers for education level")
                 
#Plot and detect outlier for column age.
sns.boxplot(x = df["BMI"], ax = axes[2])
axes[2].set_title("Outliers bmi")

#Plot and detect outlier for column age.
sns.boxplot(x = df["Cognitive Test Score"], ax = axes[3])
axes[2].set_title("Outliers for cognitive test score")
#The below boxplot shows that there were no outliers in the dataset.
# Out:
# Text(0.5, 1.0, 'Outliers for cognitive test score')

# %%
#Exported Cleaned Dataset
Alzheimer_data = df.to_csv("Alzheimers Dataset",index = False)
Alzheimer_data
